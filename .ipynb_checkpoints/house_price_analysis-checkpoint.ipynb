# %%
import pandas as pd

# %%
df_train = pd.read_csv('train_data.csv')
df_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1309          20       FV         62.0     7500   Pave  Pave      Reg
# 1310          60       RL         62.0     7917   Pave   NaN      Reg
# 1311          20       RL         85.0    13175   Pave   NaN      Reg
# 1312          70       RL         66.0     9042   Pave   NaN      Reg
# 1313          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
df_test = pd.read_csv('test_data.csv')
df_test
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             20       RH         80.0    11622   Pave   NaN      Reg
# 1             20       RL         81.0    14267   Pave   NaN      IR1
# 2             60       RL         74.0    13830   Pave   NaN      IR1
# 3             60       RL         78.0     9978   Pave   NaN      IR1
# 4            120       RL         43.0     5005   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1600          60       RL         64.0     8633   Pave   NaN      Reg
# 1601          20       RL         60.0    10434   Pave   NaN      Reg
# 1602          20       RL         79.0    10634   Pave   NaN      Reg
# 1603          60       RL         51.0     8029   Pave   NaN      IR1
# 1604          20       RL         67.0    10083   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1314 entries, 0 to 1313
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1314 non-null   int64
#  1   MSZoning       1314 non-null   object
#  2   LotFrontage    1084 non-null   float64
#  3   LotArea        1314 non-null   int64
#  4   Street         1314 non-null   object
#  5   Alley          83 non-null     object
#  6   LotShape       1314 non-null   object
#  7   LandContour    1314 non-null   object
#  8   Utilities      1314 non-null   object
#  9   LotConfig      1314 non-null   object
#  10  LandSlope      1314 non-null   object
#  11  Neighborhood   1314 non-null   object
#  12  Condition1     1314 non-null   object
#  13  Condition2     1314 non-null   object
#  14  BldgType       1314 non-null   object
#  15  HouseStyle     1314 non-null   object
#  16  OverallQual    1314 non-null   int64
# ...

# %%
df_train.LotFrontage.unique()
# Out:
# array([ 65.,  80.,  68.,  60.,  84.,  85.,  75.,  51.,  50.,  nan,  91.,
#         66., 101.,  57.,  44., 110.,  98.,  47.,  70., 108., 112.,  74.,
#         48.,  33.,  52., 100.,  24.,  89.,  63.,  72.,  81.,  95.,  69.,
#         21.,  32.,  78., 122., 105.,  73.,  77.,  64.,  94.,  61.,  34.,
#         90.,  55.,  88.,  82.,  71., 120., 107.,  92., 134.,  40.,  62.,
#         86., 141.,  97.,  54.,  41.,  79., 174.,  76.,  99.,  67.,  43.,
#        103.,  93., 129.,  83.,  35.,  37., 118.,  87., 116., 150., 111.,
#         49.,  96.,  59.,  36.,  56., 102.,  58.,  38., 109., 130.,  53.,
#        137.,  30.,  45., 106.,  42.,  39., 114., 128., 149., 313., 121.,
#        115., 104., 168., 182., 138., 160., 152., 124., 153.,  46.])

# %%
df_train.LotFrontage.fillna(0, inplace = True)

# %%
df_train.Alley.unique()
# Out:
# array([nan, 'Grvl', 'Pave'], dtype=object)

# %%
df_train.Alley.fillna('No Alley', inplace=True)

# %%
df_train.MasVnrType.unique()
# Out:
# array(['BrkFace', 'None', 'Stone', 'BrkCmn', nan], dtype=object)

# %%
df_train.MasVnrType.fillna('No Type', inplace = True)

# %%
df_train.MasVnrArea.unique()
# Out:
# array([1.960e+02, 0.000e+00, 1.620e+02, 3.500e+02, 1.860e+02, 2.860e+02,
#        3.060e+02, 2.120e+02, 1.800e+02, 3.800e+02, 2.810e+02, 6.400e+02,
#        2.000e+02, 2.460e+02, 1.320e+02, 6.500e+02, 1.010e+02, 2.720e+02,
#        4.560e+02, 1.031e+03, 1.780e+02, 5.730e+02, 1.670e+02, 1.115e+03,
#        4.000e+01, 1.040e+02, 5.760e+02, 4.430e+02, 4.680e+02, 6.600e+01,
#        2.200e+01, 2.030e+02, 6.800e+01, 1.830e+02, 4.800e+01, 2.800e+01,
#        3.360e+02, 6.000e+02, 7.680e+02, 4.800e+02, 2.200e+02, 1.840e+02,
#        1.129e+03, 1.160e+02, 1.350e+02, 2.660e+02, 8.500e+01, 3.090e+02,
#        1.360e+02, 7.000e+01, 3.200e+02, 5.000e+01, 1.200e+02, 4.360e+02,
#        2.520e+02, 8.400e+01, 6.640e+02, 2.260e+02, 3.000e+02, 6.530e+02,
#        1.120e+02, 4.910e+02, 2.680e+02, 7.480e+02, 9.800e+01, 2.750e+02,
#        1.380e+02, 2.050e+02, 2.620e+02, 1.280e+02, 1.530e+02, 6.400e+01,
#        3.120e+02, 1.600e+01, 9.220e+02, 2.900e+02, 1.270e+02, 5.060e+02,
# ...

# %%
df_train.MasVnrArea.fillna(0, inplace=True)

# %%
df_train.BsmtQual.unique()
# Out:
# array(['Gd', 'TA', 'Ex', 'Fa', nan], dtype=object)

# %%
df_train.BsmtQual.fillna('Not Applicable', inplace=True)

# %%
df_train.BsmtCond.unique()
# Out:
# array(['TA', 'Gd', 'Fa', nan, 'Po'], dtype=object)

# %%
df_train.BsmtCond.fillna('Not Applicable', inplace=True)

# %%
df_train.BsmtExposure.unique()
# Out:
# array(['No', 'Gd', 'Mn', 'Av', nan], dtype=object)

# %%
df_train.BsmtExposure.fillna('Not Applicable', inplace=True)

# %%
df_train.BsmtFinType1.unique()
# Out:
# array(['GLQ', 'ALQ', 'Unf', 'BLQ', 'Rec', 'LwQ', nan], dtype=object)

# %%
df_train.BsmtFinType1.fillna('No Basement', inplace=True)

# %%
df_train.BsmtFinType2.unique()
# Out:
# array(['Unf', 'LwQ', 'BLQ', 'GLQ', nan, 'Rec', 'ALQ'], dtype=object)

# %%
df_train.BsmtFinType2.fillna('No Basement', inplace=True)

# %%
df_train.Electrical.unique()
# Out:
# array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix', nan], dtype=object)

# %%
df_train.Electrical.fillna('Not Applicable', inplace=True)

# %%
df_train.FireplaceQu.unique()
# Out:
# array([nan, 'TA', 'Gd', 'Fa', 'Ex', 'Po'], dtype=object)

# %%
df_train.FireplaceQu.fillna('Not Applicable', inplace=True)

# %%
df_train.GarageType.unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', nan, 'CarPort', 'Basment', '2Types'],
#       dtype=object)

# %%
df_train.GarageType.fillna('No Garage', inplace=True)

# %%
df_train.GarageYrBlt.unique()
# Out:
# array([2003., 1976., 2001., 1998., 2000., 1993., 2004., 1931., 1939.,
#        2005., 1962., 2006., 1960., 1991., 1970., 1930., 2002., 2007.,
#        2008., 1957., 1920., 1966., 1959., 1995., 1954., 1953., 1965.,
#        1983., 1977.,   nan, 1997., 1985., 1963., 1964., 1999., 1973.,
#        1935., 1990., 1945., 1987., 1989., 1915., 1956., 1948., 1968.,
#        1974., 1950., 1961., 1921., 1900., 1979., 2009., 1951., 1969.,
#        1958., 1967., 1936., 1975., 1971., 1923., 1984., 1926., 1955.,
#        1981., 1986., 1988., 1916., 1932., 1972., 1918., 1980., 1924.,
#        1996., 1940., 1949., 1994., 1910., 1978., 1982., 1992., 1925.,
#        1941., 2010., 1927., 1947., 1937., 1942., 1952., 1928., 1922.,
#        1934., 1906., 1914., 1946., 1908., 1938., 1929., 1933.])

# %%
df_train.GarageYrBlt.fillna(0, inplace=True)

# %%
df_train.GarageFinish.unique()
# Out:
# array(['RFn', 'Unf', 'Fin', nan], dtype=object)

# %%
df_train.GarageFinish.fillna('No Garage', inplace=True)

# %%
df_train.GarageQual.unique()
# Out:
# array(['TA', 'Fa', 'Gd', nan, 'Ex', 'Po'], dtype=object)

# %%
df_train.GarageQual.fillna('No Garage', inplace=True)

# %%
df_train.GarageCond.unique()
# Out:
# array(['TA', 'Fa', 'Gd', nan, 'Po', 'Ex'], dtype=object)

# %%
df_train.GarageCond.fillna('No Garage', inplace=True)

# %%
df_train = df_train.drop(['PoolQC','Fence','MiscFeature'],axis=1)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1314 entries, 0 to 1313
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1314 non-null   int64
#  1   MSZoning       1314 non-null   object
#  2   LotFrontage    1314 non-null   float64
#  3   LotArea        1314 non-null   int64
#  4   Street         1314 non-null   object
#  5   Alley          1314 non-null   object
#  6   LotShape       1314 non-null   object
#  7   LandContour    1314 non-null   object
#  8   Utilities      1314 non-null   object
#  9   LotConfig      1314 non-null   object
#  10  LandSlope      1314 non-null   object
#  11  Neighborhood   1314 non-null   object
#  12  Condition1     1314 non-null   object
#  13  Condition2     1314 non-null   object
#  14  BldgType       1314 non-null   object
#  15  HouseStyle     1314 non-null   object
#  16  OverallQual    1314 non-null   int64
# ...

# %%
df_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street     Alley LotShape  \
# 0             60       RL         65.0     8450   Pave  No Alley      Reg
# 1             20       RL         80.0     9600   Pave  No Alley      Reg
# 2             60       RL         68.0    11250   Pave  No Alley      IR1
# 3             70       RL         60.0     9550   Pave  No Alley      IR1
# 4             60       RL         84.0    14260   Pave  No Alley      IR1
# ...          ...      ...          ...      ...    ...       ...      ...
# 1309          20       FV         62.0     7500   Pave      Pave      Reg
# 1310          60       RL         62.0     7917   Pave  No Alley      Reg
# 1311          20       RL         85.0    13175   Pave  No Alley      Reg
# 1312          70       RL         66.0     9042   Pave  No Alley      Reg
# 1313          20       RL         75.0     9937   Pave  No Alley      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for i in df_train.columns:
    plt.figure(figsize=(20,3))
    plt.hist(df_train[i], density=True)
    plt.title(i)
# Out:
# <ipython-input-41-8e1e02bacab6>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(20,3))

# %%
for i in df_train.columns[0:-1]:
    plt.figure(figsize=(20,3))
    sns.scatterplot(x=i,y='SalePrice',data=df_train)
# Out:
# <ipython-input-42-8f8c7e05668a>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(20,3))

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df_train.corr(), annot=True)

# %%
df_1 = df_train

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

cat_cols = df_1.select_dtypes(include=['object']).copy()
cat_cols
# Out:
#      MSZoning Street     Alley LotShape LandContour Utilities LotConfig  \
# 0          RL   Pave  No Alley      Reg         Lvl    AllPub    Inside
# 1          RL   Pave  No Alley      Reg         Lvl    AllPub       FR2
# 2          RL   Pave  No Alley      IR1         Lvl    AllPub    Inside
# 3          RL   Pave  No Alley      IR1         Lvl    AllPub    Corner
# 4          RL   Pave  No Alley      IR1         Lvl    AllPub       FR2
# ...       ...    ...       ...      ...         ...       ...       ...
# 1309       FV   Pave      Pave      Reg         Lvl    AllPub    Inside
# 1310       RL   Pave  No Alley      Reg         Lvl    AllPub    Inside
# 1311       RL   Pave  No Alley      Reg         Lvl    AllPub    Inside
# 1312       RL   Pave  No Alley      Reg         Lvl    AllPub    Inside
# 1313       RL   Pave  No Alley      Reg         Lvl    AllPub    Inside
#
#      LandSlope Neighborhood Condition1  ... KitchenQual Functional  \
# ...

# %%
for i in cat_cols.columns:
    df_1[i] = le.fit_transform(df_1[i])

# %%
df_1
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0             60         3         65.0     8450       1      1         3
# 1             20         3         80.0     9600       1      1         3
# 2             60         3         68.0    11250       1      1         0
# 3             70         3         60.0     9550       1      1         0
# 4             60         3         84.0    14260       1      1         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1309          20         1         62.0     7500       1      2         3
# 1310          60         3         62.0     7917       1      1         3
# 1311          20         3         85.0    13175       1      1         3
# 1312          70         3         66.0     9042       1      1         3
# 1313          20         3         75.0     9937       1      1         3
#
#       LandContour  Utilities  LotConfig  ...  EnclosedPorch  3SsnPorch  \
# ...
